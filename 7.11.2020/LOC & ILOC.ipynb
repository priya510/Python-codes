# %%
import pandas as pd
df=pd.DataFrame([[0.23,1.56,-0.45],
                 [1.2,-2.1,1.5],
                 [-5.1,3.2,-6.5],
                 [0.25,-0.36,-89],
                 [0.39,-0.78,-1.58]],index=["a","c","e","f","h"],columns=["one","two","three"])

df=df.reindex(["a","b","c","d","e","f","g","h"])

# %%
df
# Out:
#     one   two  three
# a  0.23  1.56  -0.45
# b   NaN   NaN    NaN
# c  1.20 -2.10   1.50
# d   NaN   NaN    NaN
# e -5.10  3.20  -6.50
# f  0.25 -0.36 -89.00
# g   NaN   NaN    NaN
# h  0.39 -0.78  -1.58

# %%
df["one"]
# Out:
# a    0.23
# b     NaN
# c    1.20
# d     NaN
# e   -5.10
# f    0.25
# g     NaN
# h    0.39
# Name: one, dtype: float64

# %%
df[["one","two"]]
# Out:
#     one   two
# a  0.23  1.56
# b   NaN   NaN
# c  1.20 -2.10
# d   NaN   NaN
# e -5.10  3.20
# f  0.25 -0.36
# g   NaN   NaN
# h  0.39 -0.78

# %%
#Fetch column by its index (index starts from zero)
df.iloc[:,1]
# Out:
# a    1.56
# b     NaN
# c   -2.10
# d     NaN
# e    3.20
# f   -0.36
# g     NaN
# h   -0.78
# Name: two, dtype: float64

# %%
#Fetch columns by index (index starts from zero)
df.iloc[:,0:2]
# Out:
#     one   two
# a  0.23  1.56
# b   NaN   NaN
# c  1.20 -2.10
# d   NaN   NaN
# e -5.10  3.20
# f  0.25 -0.36
# g   NaN   NaN
# h  0.39 -0.78

# %%
#Fetch columns by index (index starts from zero)
df.iloc[:,0:3:2]
# Out:
#     one  three
# a  0.23  -0.45
# b   NaN    NaN
# c  1.20   1.50
# d   NaN    NaN
# e -5.10  -6.50
# f  0.25 -89.00
# g   NaN    NaN
# h  0.39  -1.58

# %%
#Fetch column by its name
df.loc[:,"one"]
# Out:
# a    0.23
# b     NaN
# c    1.20
# d     NaN
# e   -5.10
# f    0.25
# g     NaN
# h    0.39
# Name: one, dtype: float64

# %%
#Fetch columns by name
df.loc[:,["one","three"]]
# Out:
#     one  three
# a  0.23  -0.45
# b   NaN    NaN
# c  1.20   1.50
# d   NaN    NaN
# e -5.10  -6.50
# f  0.25 -89.00
# g   NaN    NaN
# h  0.39  -1.58

# %%
#Fetch columns by name
df.loc[:,"one":"three"]
# Out:
#     one   two  three
# a  0.23  1.56  -0.45
# b   NaN   NaN    NaN
# c  1.20 -2.10   1.50
# d   NaN   NaN    NaN
# e -5.10  3.20  -6.50
# f  0.25 -0.36 -89.00
# g   NaN   NaN    NaN
# h  0.39 -0.78  -1.58

# %%
#Pick row by index number
df.iloc[1]
# Out:
# one     NaN
# two     NaN
# three   NaN
# Name: b, dtype: float64

# %%
df.loc["b"]
# Out:
# one     NaN
# two     NaN
# three   NaN
# Name: b, dtype: float64

# %%
df.iloc[0:3,]
# Out:
#     one   two  three
# a  0.23  1.56  -0.45
# b   NaN   NaN    NaN
# c  1.20 -2.10   1.50

# %%
df.loc["b"]=[1.23,23,45]

# %%
df
# Out:
#     one    two  three
# a  0.23   1.56  -0.45
# b  1.23  23.00  45.00
# c  1.20  -2.10   1.50
# d   NaN    NaN    NaN
# e -5.10   3.20  -6.50
# f  0.25  -0.36 -89.00
# g   NaN    NaN    NaN
# h  0.39  -0.78  -1.58

# %%
df.loc["b","two"]=25

# %%
df
# Out:
#     one    two  three
# a  0.23   1.56  -0.45
# b  1.23  25.00  45.00
# c  1.20  -2.10   1.50
# d   NaN    NaN    NaN
# e -5.10   3.20  -6.50
# f  0.25  -0.36 -89.00
# g   NaN    NaN    NaN
# h  0.39  -0.78  -1.58

# %%
df[df["two"]==25]["two"]=45
# Out:
# <ipython-input-18-a608e91faf1c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df["two"]==25]["two"]=45

# %%
df
# Out:
#     one    two  three
# a  0.23   1.56  -0.45
# b  1.23  25.00  45.00
# c  1.20  -2.10   1.50
# d   NaN    NaN    NaN
# e -5.10   3.20  -6.50
# f  0.25  -0.36 -89.00
# g   NaN    NaN    NaN
# h  0.39  -0.78  -1.58
