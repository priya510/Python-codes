# %%
activities=["sleep","eat","play","work"]
hours=[8,3,4,9]

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(hours,labels=activities,colors=("r","g","b","y"),radius=2,
       autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1f340316188>,
# ...
#  [Text(1.099999940539023, 1.905255922655575, 'sleep'),
#   Text(-1.7453774322353728, 1.3392750348765028, 'eat'),
#   Text(-2.1250367734098994, -0.5694020650257989, 'play'),
#   Text(0.8419037415028523, -2.0325348927001228, 'work')],
#  [Text(0.5999999675667398, 1.039230503266677, '33.33%'),
#   Text(-0.9520240539465668, 0.7305136553871833, '12.50%'),
#   Text(-1.1591109673144906, -0.3105829445595266, '16.67%'),
#   Text(0.4592202226379194, -1.1086553960182486, '37.50%')])
